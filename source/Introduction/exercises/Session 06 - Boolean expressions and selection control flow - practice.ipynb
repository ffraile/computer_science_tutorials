# %% [markdown]
# # Session 06 — Practice: Boolean expressions and selection control flow
#
# This practice has two blocks:
#
# - **Block A — Reinforcement:** predict, implement, test and explain.
# - **Block B — Certification-style scenarios:** make a defensible decision in a realistic situation.

# %% [markdown]
# ## Working rules
#
# 1. Predict before executing.
# 2. Change one relevant input at a time.
# 3. Test the boundary and at least one value on each side.
# 4. When reviewing AI-generated code, explain the requirement before accepting a correction.
# 5. Use only variables, basic types, operators, built-in functions and conditional structures introduced so far.

# %% [markdown]
# # Block A — Reinforcement

# %% [markdown]
# ## A1. Predict comparisons
#
# For every expression, predict its value and type.

# %%
booked_places = 28
capacity = 30
minimum_order = 50.0
order_total = 50.0
request_status = "pending"

print(booked_places < capacity)
print(booked_places == capacity)
print(order_total >= minimum_order)
print(request_status != "approved")
print(type(order_total >= minimum_order))

# %% [markdown]
# ## A2. Write the comparison
#
# Create one Boolean variable for each rule:
#
# 1. `stock` is at least `requested_units`.
# 2. `delivery_days` is greater than `promised_days`.
# 3. `department` is not equal to `"Finance"`.
# 4. `invoice_total` is exactly equal to `approved_total`.

# %%
stock = 12
requested_units = 10
delivery_days = 6
promised_days = 5
department = "Operations"
invoice_total = 850.0
approved_total = 850.0

# Create and print the four Boolean variables here.

# %% [markdown]
# ## A3. Add an optional warning with `if`
#
# A logistics dashboard should display `"Review delay"` only when `delay_minutes` is greater than 10. Otherwise, it should keep the initial message `"On schedule"`.
#
# Implement the rule with one `if` statement. Test 10 and 11 minutes and explain the boundary.

# %%
delay_minutes = 10
message = "On schedule"

# Add the if statement here.

print(message)

# %% [markdown]
# ## A4. Select one of two outcomes
#
# An expense request is within budget when `request_amount <= remaining_budget`. Use `if-else` to assign either `"Within budget"` or `"Budget exceeded"`. Test equality and one amount above the budget.

# %%
request_amount = 1200
remaining_budget = 1200

# Write the if-else statement here.

# %% [markdown]
# ## A5. Require two conditions with `and`
#
# An order may be dispatched only when it is paid and all requested units are in stock. Create `can_dispatch`, then use `if-else` to print the operational decision. Test each condition as `False` separately.

# %%
is_paid = True
stock = 8
requested_units = 6

# Create can_dispatch and select the output here.

# %% [markdown]
# ## A6. Alternatives and exclusions
#
# A document may be opened when the user is its owner or is an administrator, provided that the account is not suspended. Write a readable compound condition using `or`, `and`, `not` and parentheses. Test at least four combinations.

# %%
is_owner = False
is_administrator = True
account_suspended = False

# Create can_open_document and print it here.

# %% [markdown]
# ## A7. Prioritise outcomes
#
# A support request should receive exactly one classification:
#
# 1. `"Critical"` when the service is unavailable.
# 2. `"High"` when data may be lost.
# 3. `"Medium"` when response time exceeds 5 seconds.
# 4. `"Normal"` otherwise.
#
# Implement the policy with `if-elif-else`. Create a case where several conditions are true and explain why only one branch runs.

# %%
service_unavailable = False
possible_data_loss = True
response_time = 8.2

# Implement and print the classification here.

# %% [markdown]
# ## A8. Review AI-generated code
#
# An AI assistant proposes:
#
# ```python
# role = "viewer"
#
# if role == "administrator" or "owner":
#     permission = "Edit"
# else:
#     permission = "Read only"
# ```
#
# Before editing:
#
# 1. Predict the result.
# 2. State the intended requirement in plain language.
# 3. Identify why the condition does not test both alternatives.
# 4. Apply the smallest correction.
# 5. Test `viewer`, `owner` and `administrator`.

# %%
# Write and test the corrected version here.

# %% [markdown]
# ## A9. Design boundary tests
#
# Free shipping applies when an order total is at least 50 euros.
#
# 1. Write the comparison.
# 2. Test `49.99`, `50.00` and `50.01`.
# 3. Explain why testing only `80.00` would provide weak evidence.

# %%
order_total = 50.00

# Evaluate the rule and print the decision here.

# %% [markdown]
# # Block B — Certification-style scenarios
#
# Choose the best answer and justify it using the requirement, the condition and relevant test evidence.

# %% [markdown]
# ## Scenario 1 — Approval threshold
#
# A purchase must be reviewed when its value is **at least** 5,000 euros. An AI assistant generates:
#
# ```python
# if purchase_value > 5000:
#     review_required = True
# else:
#     review_required = False
# ```
#
# Which review is correct?
#
# A. Accept it because values above 5,000 are reviewed.
# B. Replace `>` with `>=` because exactly 5,000 must also be reviewed.
# C. Replace `>` with `==` because only 5,000 must be reviewed.
# D. Replace the condition with `purchase_value != 5000`.
#
# **Explain your choice**

# %% [markdown]
# ## Scenario 2 — Maximum room capacity
#
# A meeting room has capacity 12. A new person may enter only when the current number of occupants is below 12. Which condition implements the rule?
#
# A. `occupants <= 12`
# B. `occupants < 12`
# C. `occupants == 12`
# D. `occupants > 12`
#
# **Explain your choice and explanation for the value 12:**

# %% [markdown]
# ## Scenario 3 — Alternative workflow states
#
# A report can be edited while its status is `"draft"` or `"returned"`. An AI assistant suggests:
#
# ```python
# can_edit = status == "draft" or "returned"
# ```
#
# Which correction is best?
#
# A. `can_edit = status == "draft" and "returned"`
# B. `can_edit = status == ("draft" or "returned")`
# C. `can_edit = status == "draft" or status == "returned"`
# D. `can_edit = status != "draft"`
#
# **Your choice and the three values you would test:**

# %% [markdown]
# ## Scenario 4 — Secure document access
#
# A user may open a confidential document when they have permission and their account is not suspended. Which condition states the requirement most directly?
#
# A. `has_permission or not account_suspended`
# B. `has_permission and not account_suspended`
# C. `not has_permission and account_suspended`
# D. `has_permission and account_suspended`
#
# **Your choice and a test that should deny access:**

# %% [markdown]
# ## Scenario 5 — Priority classification
#
# A service request is critical when the service is unavailable. Otherwise, it is high priority when data may be lost, and normal in every other case. Which structure best guarantees one classification?
#
# A. Two independent `if` statements with no default.
# B. One `if-elif-else` chain ordered from critical to normal.
# C. One `if` that checks only possible data loss.
# D. An `else` before the conditions.
#
# **Your choice and explanation of branch priority:**

# %% [markdown]
# ## Scenario 6 — Two actions may be necessary
#
# A delayed shipment may require a customer notification. A high-value shipment may also require manager approval. When both conditions are true, both actions must occur. Which design is appropriate?
#
# A. Two independent `if` statements.
# B. One `if-elif` chain.
# C. One `else` block only.
# D. Compare the two Boolean values with `==` and take no action.
#
# **Your choice and explanation of what happens when both are true:**

# %% [markdown]
# ## Scenario 7 — Reversing a restriction
#
# The variable `account_blocked` records whether an account is blocked. Which expression is true exactly when the account is allowed?
#
# A. `account_blocked`
# B. `not account_blocked`
# C. `account_blocked and True`
# D. `account_blocked or True`
#
# **Your choice and values for both possible account states:**

# %% [markdown]
# ## Scenario 8 — Validating AI-generated conditional code
#
# An assistant generates a discount rule for orders of at least 100 euros. Which test set gives the strongest compact evidence about the threshold and both branches?
#
# A. `150`, `200`, `500`
# B. `0`, `10`, `20`
# C. `99.99`, `100.00`, `100.01`
# D. `100`, `100`, `100`
#
# **Your choice and explanation of what each value checks:**

# %% [markdown]
# # Final reflection
#
# 1. Which mistake is more difficult to detect: code that raises an exception or a plausible but incorrect condition? Why?
# 2. How does a plain-language requirement help you review AI-generated code?
# 3. Why should a test set include the exact boundary?
# 4. When should multiple actions use independent `if` statements instead of `if-elif-else`?
# 5. Which concept from this session do you need to practise again?
