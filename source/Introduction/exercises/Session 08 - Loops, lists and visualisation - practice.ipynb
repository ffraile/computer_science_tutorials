# %% [markdown]
# # Session 08 — Loops, lists and visualisation
# ## Practice
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ffraile/computer_science_tutorials/blob/main/source/Introduction/exercises/Session%2008%20-%20Loops%2C%20lists%20and%20visualisation%20-%20practice.ipynb) [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/ffraile/computer_science_tutorials/main?labpath=source%2FIntroduction%2Fexercises%2FSession%2008%20-%20Loops%2C%20lists%20and%20visualisation%20-%20practice.ipynb) [![Github](https://img.shields.io/badge/download-github-blue?logo=github)](https://github.com/ffraile/computer_science_tutorials/raw/main/source/Introduction/exercises/Session%2008%20-%20Loops%2C%20lists%20and%20visualisation%20-%20practice.ipynb)

# %% [markdown]
# This notebook contains two blocks:
#
# - **Block A — Reinforcement:** predict, trace, complete and test short programs.
# - **Block B — Certification-style scenarios:** choose the best decision in a realistic context and justify it.
#
# The objective is not only to obtain the expected output, but to explain why the loop, list or index is appropriate.

# %% [markdown]
# ## Working rules
#
# 1. Predict before executing.
# 2. For loop questions, write a short trace.
# 3. Make the smallest change that solves the problem.
# 4. Test normal values and at least one boundary case.
# 5. If you use an AI assistant, ask it to review your reasoning before asking for code.
# 6. Be ready to explain every line you keep.

# %% [markdown]
# # Block A — Reinforcement

# %% [markdown]
# ## A1. Trace direct iteration
#
# A café records the number of orders received during four time slots.
#
# Before running the cell, write the four values taken by `orders` and the exact output. Then explain why the final message is displayed once.

# %%
orders_by_slot = [12, 15, 11, 18]

for orders in orders_by_slot:
    print("Orders received:", orders)

print("All time slots processed.")

# %% [markdown]
# ## A2. Reason about `range()`
#
# Without running code, write the sequence produced by each expression and state the number of iterations:
#
# 1. `range(5)`
# 2. `range(2, 7)`
# 3. `range(1, 9, 2)`
# 4. `range(4, 4)`
#
# Then use the cell to verify your predictions.

# %%
for value in range(5):
    print(value)

# Replace range(5) with the other expressions, one at a time.

# %% [markdown]
# ## A3. Build a transformed list
#
# A delivery service stores durations in minutes. A reporting system needs seconds.
#
# Complete the loop so that `durations_seconds` contains every duration multiplied by `60`. Do not write the converted values manually.

# %%
durations_minutes = [12, 8, 15, 10]
durations_seconds = []

for duration in durations_minutes:
    # Calculate the duration in seconds.
    # Append the result to durations_seconds.
    pass

print(durations_seconds)
# Expected: [720, 480, 900, 600]

# %% [markdown]
# ## A4. Accumulate a total
#
# A workshop records the energy used by four machines during one hour. Calculate the total using a loop.
#
# Trace `total_energy` after every iteration and test your result.

# %%
energy_by_machine = [4.2, 3.8, 5.1, 2.9]
total_energy = 0

# Write a for loop that updates total_energy.

print("Total energy (kWh):", total_energy)
# Expected: 16.0

# %% [markdown]
# ## A5. Preserve a running series
#
# A new online service begins with `200` registered users. The list contains the new users gained each week.
#
# Create `total_users_by_week` so that it contains the initial total followed by the total after every week.

# %%
initial_users = 200
new_users_by_week = [25, 30, 20, 35]
total_users = initial_users
total_users_by_week = [initial_users]

# Update total_users for every week.
# Preserve every updated total in total_users_by_week.

print(total_users_by_week)
# Expected: [200, 225, 255, 275, 310]

# %% [markdown]
# ## A6. Store positions that require action
#
# A warehouse checks the stock of five products. A product requires replenishment when its stock is below `10`.
#
# Store the **indices** of the products that require action. Then use those indices to display both the product name and its stock.

# %%
products = ["A12", "B07", "C03", "D18", "E05"]
stock_levels = [14, 6, 9, 20, 4]
reorder_indices = []

# Use range(len(stock_levels)) and append the relevant indices.

print("Indices to reorder:", reorder_indices)

# Use the stored indices to print each product and its stock.

# %% [markdown]
# ## A7. Connect two lists by position
#
# The lists `days` and `completed_orders` describe the same observations. Print one sentence per day using a shared index.
#
# After testing, explain what assumption the program makes about the lengths of the two lists.

# %%
days = ["Monday", "Tuesday", "Wednesday", "Thursday"]
completed_orders = [42, 47, 39, 51]

# Print: Monday -> 42 completed orders
# Continue automatically for every valid index.

# %% [markdown]
# ## A8. Plot and interpret an ordered series
#
# Represent the completed orders from A7. Include markers, axis labels, a descriptive title and a grid.
#
# Before plotting, predict where the maximum point will appear. After plotting, write one sentence that interprets the chart.

# %%
import matplotlib.pyplot as plt

# Create the plot here.
plt.show()

# %% [markdown]
# ## A9. Review code suggested by an AI assistant
#
# An assistant generated this code to preserve the cumulative revenue after each sale. The result is incorrect.
#
# 1. Predict its output.
# 2. Identify the first significant logic error.
# 3. Apply the smallest correction.
# 4. Explain why the corrected position of each instruction matters.

# %%
sales = [50, 30, 70]
revenue_history = []

for sale in sales:
    total_revenue = 0
    total_revenue = total_revenue + sale

revenue_history.append(total_revenue)
print(revenue_history)

# %% [markdown]
# ## A10. Integrated mini-case — Stock evolution
#
# A warehouse begins the day with `120` units. Positive movements are deliveries and negative movements are customer orders.
#
# Build a program that:
#
# 1. preserves the initial stock and every later stock level;
# 2. stores the indices where stock falls below the safety level;
# 3. displays the first step that requires attention, if one exists; and
# 4. plots the complete stock evolution.
#
# Test the program with a safety level that is never crossed.

# %%
initial_stock = 120
movements = [-18, -25, 40, -35, -28]
safety_level = 70

stock_history = [initial_stock]
step_numbers = [0]
alert_indices = []
current_stock = initial_stock

# 1. Process every movement and preserve the history.

# 2. Inspect stock_history and preserve alert indices.

# 3. Display the first alert step, if one exists.

# 4. Plot step_numbers against stock_history.

# %% [markdown]
# # Block B — Certification-style scenarios
#
# For every question, select the **best** answer and justify it in one or two sentences. Explain why at least one alternative is less appropriate.

# %% [markdown]
# ## B1. Scheduled quality checks
#
# A production analyst needs a loop to display check numbers `1`, `2`, `3`, `4` and `5`. Which header best meets the requirement?
#
# A. `for check in range(5):`
#
# B. `for check in range(1, 5):`
#
# C. `for check in range(1, 6):`
#
# D. `for check in range(0, 6):`

# %% [markdown]
# ## B2. Reviewing an AI-generated total
#
# An AI assistant proposes this code to total weekly expenses:
#
# ```python
# for expense in expenses:
#     total = 0
#     total = total + expense
# ```
#
# What is the best review comment?
#
# A. Replace the `for` loop with an `if` statement.
#
# B. Initialise `total` before the loop so earlier values are preserved.
#
# C. Move `total = total + expense` before the loop.
#
# D. Add `1` to the value of every expense.

# %% [markdown]
# ## B3. Finding where failures occurred
#
# A team has a list of test results and must later retrieve the test name corresponding to every failed result. Which approach provides the most useful information?
#
# A. Iterate directly over the results and store only the value `False`.
#
# B. Use `range(len(results))` and store the indices where the result is `False`.
#
# C. Store the total number of results only.
#
# D. Plot the Boolean values without preserving positions.

# %% [markdown]
# ## B4. Preserving every processed value
#
# A script converts a list of prices from euros to cents. The final list contains only one value, although every price was converted correctly during the loop. What is the most likely cause?
#
# A. `append()` was placed after the loop instead of inside it.
#
# B. The output list was created before the loop.
#
# C. The loop variable received each price.
#
# D. The conversion multiplied each value by `100`.

# %% [markdown]
# ## B5. LED sweep code review
#
# A Python test simulates an Arduino LED sweep. LEDs are connected to pins `2`, `3`, `4`, `5` and `6`, but this code never activates pin `6`:
#
# ```python
# for pin in range(2, 6):
#     turn_on(pin)
# ```
#
# Which is the smallest correct change?
#
# A. `range(2, 5)`
#
# B. `range(2, 6, 2)`
#
# C. `range(2, 7)`
#
# D. `range(1, 6)`

# %% [markdown]
# ## B6. Matplotlib rejects two series
#
# A dashboard calls `plt.plot(hours, demand)`. The list `hours` contains 24 values and `demand` contains 23. What should the analyst check first?
#
# A. Whether both lists contain the same number of corresponding observations.
#
# B. Whether all demand values are integers.
#
# C. Whether the title contains the word *demand*.
#
# D. Whether the chart uses a grid.

# %% [markdown]
# ## B7. Diagnosing an index error
#
# An AI assistant generates the following loop and Python raises `IndexError` on the last iteration:
#
# ```python
# for index in range(len(values) + 1):
#     print(values[index])
# ```
#
# Which explanation is most accurate?
#
# A. Lists cannot be used inside `for` loops.
#
# B. `range()` includes its stop value.
#
# C. The `+ 1` creates an index equal to the list length, which is outside the valid range.
#
# D. The loop must begin at index `1`.

# %% [markdown]
# ## B8. Choosing a representation for a trend
#
# A manager wants to see whether daily waiting time is increasing or decreasing throughout a week. Which solution best supports that decision?
#
# A. Keep only the final waiting time and print it.
#
# B. Preserve the ordered daily values in a list and plot them against the days.
#
# C. Sort the values before plotting, regardless of the day.
#
# D. Store only the indices where waiting time is positive.

# %% [markdown]
# # Final reflection
#
# Answer briefly:
#
# 1. When would you choose direct iteration instead of index-based iteration?
# 2. Describe one situation where preserving indices is more useful than preserving only values.
# 3. What is an off-by-one error, and how can you detect it with a manual trace?
# 4. Why does a chart require the data to be preserved before it is plotted?
# 5. Which AI-generated mistake in this notebook would be hardest to notice without tracing the program? Why?
