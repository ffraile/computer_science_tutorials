# %% [markdown]
# # Session 05 — Practice: variables, types and numeric operations
# ## Try me
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ffraile/computer_science_tutorials/blob/main/source/Introduction/exercises/Session%2005%20-%20Variables,%20types%20and%20numeric%20operations%20-%20practice.ipynb) [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/ffraile/computer_science_tutorials/main?labpath=source%2FIntroduction%2Fexercises%2FSession%2005%20-%20Variables%2C%20types%20and%20numeric%20operations%20-%20practice.ipynb) [![Github](https://img.shields.io/badge/download-github-blue?logo=github)](https://github.com/ffraile/computer_science_tutorials/raw/main/source/Introduction/exercises/Session%2005%20-%20Variables,%20types%20and%20numeric%20operations%20-%20practice.ipynb)

# %% [markdown]
# ## Working rules
#
# For each task:
#
# 1. predict before executing;
# 2. explain the relevant values and types;
# 3. make the smallest appropriate change;
# 4. verify the result with evidence.
#
# For exam-style questions, select the **best** answer and justify it in one or two sentences.

# %% [markdown]
# # Block A — Reinforcement

# %% [markdown]
# ## A1. Track the state
#
# Predict the state after each instruction.
#
# ```python
# available_units = 20
# reserved_units = 6
# available_units = available_units - reserved_units
# reserved_units = reserved_units + 2
# ```
#
# | Instruction | `available_units` | `reserved_units` |
# |---|---:|---:|
# | Initial state | — | — |
# | Line 1 | ? | ? |
# | Line 2 | ? | ? |
# | Line 3 | ? | ? |
# | Line 4 | ? | ? |
#
# Explain what the final reassignment represents.

# %%
available_units = 20
reserved_units = 6
available_units = available_units - reserved_units
reserved_units = reserved_units + 2

print(available_units)
print(reserved_units)

# %% [markdown]
# ## A2. Predict value and type
#
# For each expression, write the expected value and type before executing the cell.

# %%
print(8 + 2)
print(8 / 2)
print(8 // 3)
print(8 % 3)
print(2 ** 8)
print("8" * 2)
print(float(8))
print(str(8))

# %% [markdown]
# Which result is most likely to surprise someone who checks only whether the code runs? Explain why.

# %% [markdown]
# ## A3. Choose the operator
#
# Select the most appropriate operator for each requirement:
#
# 1. Calculate the cost of several units.
# 2. Calculate the number of complete boxes.
# 3. Calculate the units left after filling the boxes.
# 4. Calculate the area of a square.
# 5. Divide a total measurement by the number of observations.
#
# Use each selected operator in a small Python expression.

# %%
# Write and execute your five expressions here.

# %% [markdown]
# ## A4. Convert a duration
#
# Convert `26_545` seconds into complete hours, complete minutes and remaining seconds.
#
# Requirements:
#
# - use descriptive intermediate variables;
# - use both `//` and `%`;
# - explain what each variable represents.

# %%
total_seconds = 26_545

# Complete the calculation.

# %% [markdown]
# ## A5. Fix the input
#
# Predict what happens and apply the smallest appropriate correction.

# %%
number_of_people = input("Number of people: ")
price_per_person = 12.50

# Fix the calculation without changing the intended meaning.
total = number_of_people * price_per_person
print(total)

# %% [markdown]
# Explain the original type of `number_of_people`, the conversion you selected and why the corrected operation is meaningful.

# %% [markdown]
# ## A6. Make the intention explicit
#
# Use these values:
#
# ```python
# base_price = 50
# tax_rate = 0.21
# discount = 10
# ```
#
# Write two expressions:
#
# 1. Apply tax to the base price and then subtract the discount.
# 2. Subtract the discount before calculating tax on the discounted price.
#
# Use parentheses where they clarify the intended calculation, then compare the results.

# %%
base_price = 50
tax_rate = 0.21
discount = 10

# Write both expressions here.

# %% [markdown]
# ## A7. Review AI-generated code
#
# An AI assistant proposes:

# %%
unit_price = 19.95
quantity = 5

total = int(unit_price) * quantity
print(total)

# %% [markdown]
# Answer before changing the code:
#
# 1. Does it run?
# 2. Is the result correct for the original price?
# 3. What information is lost?
# 4. What minimal correction would you make?
# 5. How would you verify it?

# %%
# Write and test the corrected version here.

# %% [markdown]
# ## A8. Small implementation task
#
# Create a program that:
#
# 1. asks for the duration of an activity in minutes;
# 2. converts the input to a suitable type;
# 3. calculates complete hours and remaining minutes;
# 4. displays both results;
# 5. uses descriptive variable names.

# %%
# Implement and test your program here.

# %% [markdown]
# # Block B — Certification-style scenarios
#
# Select the **best** answer. Justify your decision using the scenario requirements, not only whether the code runs.

# %% [markdown]
# ## Scenario 1 — Input provided as text
#
# A purchasing assistant uses this code:
#
# ```python
# unit_price = 14.50
# quantity = input("Quantity: ")
# total = unit_price * quantity
# ```
#
# The program fails when calculating `total`. What is the best correction?
#
# A. `quantity = str(quantity)`
# B. `quantity = int(quantity)`
# C. `unit_price = str(unit_price)`
# D. `total = unit_price + quantity`
#
# **Your choice and justification:**

# %% [markdown]
# ## Scenario 2 — Packing devices
#
# A warehouse must pack 137 devices into boxes that hold 12 devices each. The manager needs the number of complete boxes and unpacked devices. Which solution is most appropriate?
#
# A.
# ```python
# boxes = 137 / 12
# remaining = 137 / 12
# ```
#
# B.
# ```python
# boxes = 137 // 12
# remaining = 137 % 12
# ```
#
# C.
# ```python
# boxes = 137 % 12
# remaining = 137 // 12
# ```
#
# D.
# ```python
# boxes = int(137 / 12)
# remaining = 137 - 12
# ```
#
# **Your choice and justification:**

# %% [markdown]
# ## Scenario 3 — Reviewing an AI suggestion
#
# An AI assistant proposes:
#
# ```python
# measurement = int(23.87)
# ```
#
# The measurement will be used to check whether a manufacturing process stays within a tolerance of `0.1` degrees. What is the best decision?
#
# A. Accept it because integers are easier to compare.
# B. Accept it because `int()` rounds to the nearest integer.
# C. Reject it because the conversion removes precision required by the process.
# D. Convert the measurement to `str` instead.
#
# **Your choice and justification:**

# %% [markdown]
# ## Scenario 4 — Updating inventory
#
# An AI assistant claims that this instruction is invalid because a value cannot be equal to itself minus three:
#
# ```python
# stock = stock - 3
# ```
#
# Which explanation is correct?
#
# A. The assistant is correct because Python follows mathematical equality.
# B. Python evaluates the right-hand expression and assigns its result to `stock`.
# C. Python subtracts three but does not update the variable.
# D. The instruction is valid only when `stock` is a string.
#
# **Your choice and justification:**

# %% [markdown]
# ## Scenario 5 — Billing calculation
#
# A program must calculate the cost of several units and then add shipping:
#
# ```python
# total = unit_price * quantity + shipping
# ```
#
# An AI assistant changes it to:
#
# ```python
# total = unit_price * (quantity + shipping)
# ```
#
# What should the reviewer conclude?
#
# A. Both expressions are always equivalent.
# B. The second expression incorrectly treats shipping as additional units.
# C. The first expression ignores shipping.
# D. Parentheses never affect numeric results.
#
# **Your choice and justification:**

# %% [markdown]
# ## Scenario 6 — Sensor data
#
# A monitoring script receives:
#
# ```python
# reading = "23.7"
# reference = 25.0
# difference = reference - reading
# ```
#
# What is the best minimal correction?
#
# A. `reading = int(reading)`
# B. `reading = float(reading)`
# C. `reference = str(reference)`
# D. `difference = reference + reading`
#
# **Your choice and justification:**

# %% [markdown]
# ## Scenario 7 — Selecting suitable precision
#
# An AI assistant suggests:
#
# ```python
# average_cost = int(total_cost / number_of_items)
# ```
#
# The value will be shown in a financial report where cents are relevant. What is the best implementation?
#
# A. `average_cost = total_cost // number_of_items`
# B. `average_cost = int(total_cost / number_of_items)`
# C. `average_cost = round(total_cost / number_of_items, 2)`
# D. `average_cost = str(total_cost)`
#
# **Your choice and justification:**

# %% [markdown]
# ## Scenario 8 — Valid result, wrong meaning
#
# A program receives `"5"` from `input()` and executes:
#
# ```python
# copies = "5" * 2
# ```
#
# The result is `"55"` and no exception is raised. What is the best interpretation?
#
# A. The code is correct because it executed without an error.
# B. Python converted `"5"` to an integer automatically.
# C. The operation repeated a string, producing a valid but semantically incorrect result.
# D. Multiplication cannot be used with strings.
#
# **Your choice and justification:**

# %% [markdown]
# # Final reflection
#
# 1. Which mistake can produce a plausible-looking result without raising an exception?
# 2. Why must a reviewer understand the required meaning and precision?
# 3. What evidence should you request before accepting code proposed by an AI assistant?
# 4. Which concept from this session do you need to practise again?
