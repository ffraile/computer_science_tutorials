# %% [markdown]
# # Hello world
# ## Try me
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ffraile/computer_science_tutorials/blob/main/source/Introduction/follow_along/session%2003%20-%20follow_along.ipynb)[![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/ffraile/computer_science_tutorials/main?labpath=source%2FIntroduction%2Ffollow_along%2Fsession%2003%20-%20follow_along.ipynb)[![Github](https://img.shields.io/badge/download-github-blue?logo=github)](https://github.com/ffraile/computer_science_tutorials/raw/main/source/Introduction/follow_along/session%2003%20-%20follow_along.ipynb)
#
# This is a text cell. You can use text cells to write explanations, instructions, or any other information you want to include in your notebook. Text cells support Markdown, which allows you to format your text, add links, images, and more.
#
# You can create lists like this:
# - Item 1
# - Item 2
# - Item 3
# - ...
#
# You can also create tables:
#
# | Column 1 | Column 2 | Column 3 |
# |----------|----------|----------|
# | Row 1   | Row 1   | Row 1   |
# | Row 2   | Row 2   | Row 2   |
# | Row 3   | Row 3   | Row 3   |
#
# And many more! You can check the [Markdown Guide](https://www.markdownguide.org/) or this [tutorial](../tutorials/Working%20with%20Markdown%20cells.ipynb) for more information on how to use Markdown in your notebooks.

# %%
# This is a comment in a code cell.
# Comments are ignored by the interpreter and help document the code
print("Hello world")
