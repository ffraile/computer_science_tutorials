# %% [markdown]
# ### Exercise 1
# Review the following program code:
#
# ```python
# user_message = input("Enter a binary sequence: ")
# print(user_message[::-1])
# ```
# **a.** What is the output of the program if the user enters the sequence ```101010```? Explain why. **(1 point)**
# The output is 010101 because the [::-1] reverses the string.
#
# ### Exercise 2
# Review the following program code:
#
# ```python
# my_name = "Thomas"
# your_guess = ""
# max_attempts = 5
# counter = 0
# while (your_guess != my_name) and (counter < max_attempts):
#     your_guess = input("What is my name? ")
#     if your_guess == my_name:
#         print("Yes, that is my name!")
#         break
#     else:
#         print("No, that is not my name!")
#         counter += 1
#         print("Here´s a clue, my name starts with " + my_name[0:counter])
#         print("Try again!")
#
# print("You needed " + str(counter) + " attempts to guess my name")
# ```
# **a.** Describe in your words what the program does? **(1 point)**
# The program asks the user to guess the name "Thomas". If the user guesses correctly, the program ends. If the user guesses incorrectly, the program gives a clue and asks the user to guess again. The clues consist of the first letter(s) of the name, the first clue is "T", and if the user needs a third attempt, the clue is "Th", and so on. The program ends after 5 attempts.
#
# **b.** What is the output of the program if the user enters the name ```Luke```? **(0.5 points)**
# No, that is not my name!
# Here´s a clue, my name starts with T
# Try again!
#
# ### Exercise 3
# Review the following program code:
#
# ```python
# import random
# all_chars = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890!?.:,'{}[]+-*/=_@#$%^&()~"
#
# p_len = int(input("Enter the length: "))
# p_string = ""
# for i in range(p_len):
#     a_random_idx = random.randint(0, len(all_chars)-1)
#     p_string = p_string + all_chars[a_random_idx]
#
# print(p_string)
# ```
#
# And recall that the function ```random.randint(a, b)``` returns a random integer between `a` and `b` (inclusive), and the function ```range(a)``` returns an iterable object that contains all integers from 0 to `a-1` (inclusive).
#
# Answer the following questions:
#
# **a.** Describe in your own words what the code does. What would you use this code for? **(2 points)**
# The code asks the user for a integer value, and then creates a random string of characters with the length of the integer value provided by the user. The code could be used to create for instance a random password.
#
# ## Exercise 4
# Review the following program code:
#
# ```python
# a_list = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# b_list = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# c_list = []
# for i in range(len(a_list)):
#     if i % 2 == 0:
#         c_list.append(a_list[i] + b_list[i])
# ```
#
# And recall that the method ```list.append(x)``` adds the element `x` to the end of the list ```list```.
#
# **a.** What is the value of the variable c_list at the end of the program? **(2 points)**
# The value of c_list is [2, 6, 10, 14, 18].
#
# ### Exercise 5
# Review the following program code:
#
# ```python
# x = int(input("Enter an integer number: "))
# i = 0
# result = ""
# while x > 2**i:
#     b = (x // (2**i)) % 2
#     i = i + 1
#     result = str(b) + result
# print(result)
# ```
# **a.** What does the program do? **(1.5 points)**
# The program asks the user for an integer number, and then converts the number to a string representing the value of the number in binary.
#
# **b.** What is the output of the program if the user enters the number 10? **(0.5 points)**
# 1010
#
# ### Exercise 6
# Check the following dictionary:
#
# ```python
# heroes = {
#     "Batman": {
#         "full_name": "Bruce Wayne",
#         "city": "Gotham City",
#         "powers": ["intelligence", "combat"]
#         },
#     "Superman": {
#         "full_name": "Clark Kent",
#         "city": "Metropolis",
#         "powers": ["flight", "strength", "speed"]
#         },
#     "Spiderman": {
#         "full_name": "Peter Parker",
#         "city": "New York City",
#         "powers": ["agility", "strength", "speed", "wall-crawling"]
#         }
#     }
# ```
#
# **a.** What is the value of ```heroes["Batman"]["city"]```? **(0.5 points)**
# (The infamous) "Gotham City"
#
# **b.** What is the value of ```heroes["Superman"]["powers"][1]```? **(0.5 points)**
# "strength" (the second power in the list of powers of Superman)
#
# **c.** What is the value of ```heroes["Spiderman"]["powers"][-1][0]```? **(0.5 points)**
# "w" (as is the first letter of the last power in the list of powers of Spiderman)
