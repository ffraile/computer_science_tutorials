# %% [markdown]
# ### Exercise 1 (1 point)
# Review the following code:
#
# ```python
# input = int(input("Enter a number: "))
# if input % 2 == 0:
#     print("What a nice and even number!")
# else:
#     print("Uhmm, there is something odd about that number.")
# ```
# **a.** Describe in your words what the program does? (0.5 points)
# **b.** What is the output of the program if the user's input is 5? (0.5 points)
#
# ### Exercise 2 (2.5 points)
# Review the following code:
#
# ```python
# favorite_color = "blue"
# color_guess = ""
# attempt_limit = 3
# attempts = 0
# clues = ["It's a color of the sky.", "Superman wears this color.", "It's a primary color."]
# while (color_guess.lower() != favorite_color) and (attempts < attempt_limit):
#     color_guess = input("Guess my favorite color: ")
#     attempts += 1
#     if color_guess.lower() == favorite_color:
#         print("Correct! That's my favorite color.")
#     else:
#         print("Sorry, try again.")
#         print ("Hint: " + str(clues[attempts - 1]))
#         attempts_left = attempt_limit - attempts
#         print("Attempts left: " + str(attempts_left))
#
# if attempts == attempt_limit:
#     print("Sorry, you've run out of attempts.")
# ```
#
# Note that the method lower() is used to convert the user's input to lowercase (same characters but no capital letters).
#
# Answer the following questions:
# **a.** Describe in your words what the program does? (1 point)
#
# **b.** What is the output of the program if the user's guesses are Red, green, and Blue in that order? (0.5 points)
#
# ### Exercise 3 (2.5 points)
# Review the following code:
#
# ```python
# n = int(input("Enter the number of terms in the harmonic series: "))
# total_sum = 0
# for i in range(1, n + 1):
#     total_sum += i / (i + 1)
#
# print(f"The sum of the series is {total_sum:.2f}")
# ```
#
# Answer the following questions:
# **a.** Describe in your words what the program does? (1 point)
# **b.** What is the output of the program if the user's input is 5? (0.5 points)
# **c.** In general, what are the terms of the harmonic series evaluated by the program? (1 point)
#
# ### Exercise 4 (1.5 points)
# Review the following code:
#
# ```python
# goal = int(input("Enter your goal step count for today: "))
# steps_taken = int(input("Enter the number of steps you've taken today: "))
# steps_ratio = steps_taken / goal
# progress_emoji = "👟"
# goal_emoji = "🏁"
#
# if steps_ratio >= 1:
#     performance_emoji = "😸"
# elif steps_ratio >= 0.5:
#     performance_emoji = "🐱"
# else:
#     performance_emoji = "😿"
#
#
# visual_progress = progress_emoji * round(steps_ratio * 10) + goal_emoji
#
# print("Your progress today: " + visual_progress)
# print("You made the Fitty cat feel: " + performance_emoji)
# ```
#
# Answer the following questions:
# **a.** Describe in your words what the program does? (1 point)
# **b.** What is the output of the program if the user's input is 10000 and 2500 in that order? (0.5 points)
#
# ### Exercise 5 (1 point)
# Review the following code:
#
# ```python
#
# number = int(input("Enter an integer number: "))
# binary_result = bin(number)[2:-1]
# print("The binary result of the operation is" + binary_result)
# ```
# Recall that the function ```bin``` returns a text string representing the integer value passed as argument, with '0b' as a prefix. For instance ```bin(2)``` returns the string ```0b10```
#
# **a.** What is the result if the user enters the value 17? (0.5 points)
# **b.** What is the mathematical operation performed? Explain why (0.5 points)
#
# ### Exercise 6 (1.5 points)
# Review the following code:
#
# ```
# vehicles = {
#     "Car": {
#         "brand": "Toyota",
#         "model": "Corolla",
#         "features": ["airbags", "bluetooth", "cruise control"]
#         },
#     "Motorcycle": {
#         "brand": "Harley-Davidson",
#         "model": "Street 750",
#         "features": ["ABS", "LED lights", "keyless start"]
#         },
#     "Bicycle": {
#         "brand": "Trek",
#         "model": "Marlin 5",
#         "features": ["front suspension", "hydraulic disc brakes", "mountain tires"]
#         }
#     }
# ```
#
# Answer the following questions:
# **a.** what is the value of ```vehicles["Car"]["brand"]```? 0.5 points
# **b.** what is the type of ```vehicles["Biciclye"]["features"]```? 0.5 points
# **c.** What is the value of ```vehicles["Motorcycle"]["features"][::-1]```? 0.5 points
