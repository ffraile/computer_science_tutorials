# %% [markdown]
# ### Exercise 1
# Review the following program code:
#
# ```python
# input_number = float(input("Enter a number"))
# if input_number > 0:
#     print("The number is positive")
# elif input_number < 0:
#     print("The number is negative")
# else:
#     print("The number is zero")
# ```
# **a.** What does this program do? Explain with your own words **(1 point)**
#
#
#
# ### Exercise 2
# Review the following code:
#
# ```python
# text = input("Enter some text: ")
#
# text_2 = text[::-1]
# if text == text_2:
#     print("True!")
# else:
#     print("No luck this time...")
# ```
# **a.** Describe in your words what the program does? **(1.5 points)**
#
# **b.** What is the output of the program if the user enters the text ```A man, a plan, a canal, Panama```? Explain why **(0.5 points)**
#
# ### Exercise 3
# Check the following code:
#
# ```python
# input_number = int(input("Enter a number: "))
# result = 1
# while input_number > 1:
#     result = result * input_number
#     input_number = input_number - 1
# ```
#
# Answer the following question:
#
# **a.** Describe in your own words what the code does. What would you use this code for? **(2 points)**
#
# **b.** What is the output of the program if the user enters the number 5? **(0.5 points)**
#
#
# ### Exercise 4
# Review the program below:
#
# ```python
# flame = "🔥"
# ice_cube = "🧊"
#
# current_temperature = float(input("What is the temperature? "))
# difference = current_temperature - 23
# no_of_emojis = round(abs(difference))
# if difference > 0:
#     print("It´s hot! " + flame * no_of_emojis)
# elif difference < 0:
#     print("It´s cold! " + ice_cube * no_of_emojis)
# else:
#     print("The temperature is perfect!")
# ```
# Recall that the built-in function ```round``` rounds a number to the nearest integer. For example, ```round(3.5)``` returns ```4```, and the function ```abs``` returns the absolute value of a number. For example, ```abs(-3)``` returns ```3```.
#
# **a.** What does the program do? Explain in your own words **(1 point)**
#
# **b.** What is the output of the program if the user enters the number 27? **(1 point)**
#
# ### Exercise 4
# Check the following program:
#
# ```python
# numbers = [2, 7, 4, 9, 12, 5, 15]
# for num in sorted(numbers, reverse=True):
#     if num % 2 == 0:
#         print(num)
# ```
#
# Recall that the function ```sorted``` returns a sorted list of the elements in the list passed as argument. The argument ```reverse=True``` indicates that the list should be sorted in descending order (from largest to smallest).
#
# **a.** What does the program do? Explain in your own words **(1 point)**
#
# **b.** What is the sequence printed by the program? **(0.5 points)**
#
# ### Exercise 5
#
# Review the following program code:
#
# ```python
# students = {
#     "Alice": {
#         "CS": 5,
#         "Math": 6
#         },
#     "Bob": {
#         "CS": 8,
#         "Math": 7
#         },
#     "Charlie": {
#         "CS": 7,
#         "Math": 8
#         },
#     "Diana": {
#         "CS": 6,
#         "Math": 6
#         }
# }
# ```
#
# Recall that the method ```dict.values()``` returns a list of the values in a dictionary. For example, ```{"a": 1, "b": 2}.values()``` returns ```[1, 2]```.
# Recall that the function ```sum``` returns the sum of the elements in a list. For example, ```sum([1, 2, 3])``` returns ```6```.
#
# **a** What is the output of the following statement ```print(students["Alice"]["CS"])```? **(0.5 points)**
#
# **b** What is the type of the value returned by the following statement ```Students["Bob"]```? **(0.5 points)**
#
# **c** What is the output of the following statement ```print(sum(students["Bob"].values())/2)```? **(0.5 points)**
